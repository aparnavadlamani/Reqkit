# %%
import csv
import numpy as np
import pandas as pd
import seaborn as sns

# %%
with open('output.csv','r') as dest_f:
    data_iter = csv.reader(dest_f,
                           delimiter = ",")
    data = [data for data in data_iter]
data_array = np.asarray(data)

print(data_array)
# Out:
# [list(['Shuttitt Uppitt', 'Nate', 'Sir Willard', 'Chris L', 'Peter Blaikie', 'Jermaine Rogers', 'Q B', 'Shaun Samuel', 'Hamish McIntyre-Bhatty', 'Leonardo Hortmann', 'James Johnson', 'Nintendo Switch', 'Monster', 'Steven Anthony Eckstine', 'Arthur Schreinemacher', 'Abdin Khan', 'Exzaviermoon', 'Paul Y', 'Amanda Owens', 'Shakil Meshram', 'Sarath S', 'JD', 'Alex Pineiro', 'Asad Shaikh', 'Lionel Mwangi', 'Shubham Shukla', 'Bernardo Moreira', 'Tiaan Flemmng', 'Theo Priosti', 'Denis Bach', 'Alexandra Wolfe', 'paquito malgesto', 'desreveR Kepler', 'Daniel Leiman', 'Shailen Sobhee', 'Anno Niem', 'Keith Prescott', 'Loreflor Mina', 'Jordan Goretti', 'Clinton Scotcher', 'vivek seran', 'Antonio Garcia', 'Ioannis Papadopoulos', 'Peter Skeberdis', 'Chad Jones', 'Kiel Jordan', 'Ненад Стефан Илић', 'Augusta Leorok', 'Gurjeet Singh', 'Norman Cates', 'Rahul Panwar', 'Michael Feliu', 'Muhammad Talha', 'Austine Njunge', 'Grant Galloway', 'Rajat Deb', 'John Smith', 'Abdul Samad K A', 'Chetachi Nwabueze', 'Elango Igo', 'Brandon Bosco', 'Luis M', 'Kumar Kc', 'Michael Theron', 'Chi Aberin', 'Josh Solwin', 'Anthony Grambo', 'M G', 'Ofili Chidinma', 'John Gile', 'Serge Lespagnard', 'Freziel Jade Natividad', 'Béla Ságodi', 'muhammad ahmad', 'Jay Marker', 'Chuck Jones', 'KING Mali', 'Greg Schermerhorn', 'Terence 1Plus', 'Aditya Agarwal', 'Malcolm Buc', 'Xper User', 'Homa Dimkpa', 'Mike Spike', 'RadioactiveRatt', 'Ananda Rizky', 'Panda', 'Christina Duncan', 'Amadeus Mozart', 'Super Cartoonist', 'Tony Mace', 'Checkers Boards', 'hywel griffiths', 'Yuki Akashiya', 'Amarbayasgalan Narantsetseg', 'Ali Tajelsir', 'Zachary Francis', 'A Google user', 'Anthony Craft', 'James Martin', 'Dr Mangler', 'Razvan Nicolae', 'Stephen Fynn', 'Obadiah King Israel', 'Amer Saleem', 'Just another stupid kid', 'Lightning spirit', 'Rachael Hildebrand', 'Thomas Sisson', 'RUs Tech maniac', 'Bhaskar Jalan', 'Ozosh Maharjan', 'Ryan X', 'soumaila napon', 'ndindi mmzA', 'Bikram Dey', 'Teh Landstander', 'bob wolf', 'lucky strikes', 'White Trash', 'Cartoon AndAnime2020', 'Esther Petersen', 'Bruce Clarkson', 'Frank Kinuthia', 'Bruce Schnitzer', 'Kenneth Lantier', 'Austin Teague', 'Saloni Jain', 'Liaqat Kham', 'Deyko', 'Mattness LP', 'marcos guzman', 'Parveen kumar', 'mbeeta Richard Edgar.', 'Yuxi', 'Zulfiqar Ali', 'Ilysha M', 'Ani Casma', 'Muhammad Abdullah Saad', 'Justin Morton', 'René Vullum', 'Ajay Pathak', 'Raghav Kabra', 'Jesse', 'Johan Larsson', 'Leon Buikstra', 'Polly Monsta', 'K.Y. Peng', 'Lucas Akorli', 'Earl Baversjo', 'Long Huynh Phi', 'mikesmultimedia', 'Reggie May', 'Glenn Armitage', 'gabe g', 'Jonathan M', 'Dora The Explorer', 'Terry Lyall', 'J-train', 'Tres Tigers', 'Aeron Hale', 'Kisan Kumar Biswal', 'Hizkia Ibrahim', 'RP S', 'Marco Ramírez', 'Bert Ward', 'Jack Marshall', 'Alex Naglich', 'Mihai Mara', 'Mutinta Handabile', 'U make my heart go uwu', 'V.V', 'Elton Veux', 'Kevin M.', 'Steve Gower', 'Tony Early', 'Ali Mojebi', 'Clayton Morrison', 'Jet Ardeshna', 'Richard Young', 'Adrian Michell', 'Ronald Jordan Jr', 'Aukash Kalyaan', 'David Watt', 'Tshwene Vincent Baloyi', 'Shane Drumbastic', 'Arlene S.', 'Greg-Snap R', 'Amin Karimi', 'john hendey', 'Saud Chaudhery', 'Julia Barnard', 'Farran', 'Hyperion Proteus', 'Joseph Marcum', 'Maximus', 'Agapia Coman', 'Ahsan Jabbar', 'Melissa Cain', 'Sydney Lewis-Picard', 'Resuri Kuro', 'Cloaked Rider', 'Terry Yim', 'Jason Mumblow', 'Anthony Vaclavicek', 'Reperak', 'Cloud Dancer', 'Chile', 'EthanJ Silver', 'Brian Sodke', 'Erick Asroid', 'Daniel Obadofin', 'Bhavin Dalal', 'Michael Ayozie', 'Kasia Brian', 'Anthony Sonnier', 'carsten e', 'JKerman511', 'ich moimeyo', 'shiva serpent', 'Brian Andrews', 'William Oyeyipo', 'Leon Lightwing', 'Horatio Baptism', 'Craig Barone', 'Akinyemi Ruth Abosede', 'Gerald Pique', 'Krishna Kumar V S', 'Ricardo Pillay', 'Jorge A. Grau', 'Bhoopalan I', 'Riku Nara', 'Nursyuhada Hassan', 'Aftab A', 'zachary brown', 'Faisal Khalil', 'Opetyr', 'Chris W', 'Family Horwat', 'Nghia Nguyen Trung', 'Donavan B LoForte RPN, RC ...
#  list(['(3.2.7) It works fine. It\'s smart to put the "Delete" option at the BOTTOM of the list. (At other users. Use FILE MANAGERS to delete videos/ images/ music/ others.) Now I hope to see better performance for non SUPER hardware. Example = One of my phones has 2 GB of RAM, but only 480x854 resolution. I...\nFull Review', 'Seek track is impossible to use. Whether I hold the fast forward or rewind button, tap the progress bar, drag the dot on the progress bar, or input seek time manually, nothing works. The behavior is erratic. This app is impossible to use for listening to audiobooks. 8 hours in one sitting with no br...\nFull Review', "I've been using the VLC Windows application for years & it's better than any others I've tried. This was the reason for choosing this app. However, the most recent update shrank the tool bar to less than full screen width and removed the ability to refresh the play list after deleting a played file....\nFull Review", "The updates just make it worse. I used to like sorting by date to easily find my latest added files. Now you can only sort by name. I just don't understand how it got less features after an update. Lots of other small issues with the later versions also. I'm actively looking for a new app as this on...\nFull Review", "I love VLC on my PC. Used to like it on my Android phone but it doesn't work on the S10+. I hate to give bad reviews but this app just doesn't work even after latest updates. Movies pauses every 2 seconds & doesn't restart. Time to look for a new video glare for android. I would prefer to use VLC, o...\nFull Review", "Glad to have the delete option back. Seems now the app has a problem keeping the filenames straight. Simply refreshing doesn't help. When I delete a file, the name is apparently assigned to a remaining file. I can only tell what the real filename is by looking at the information.", "I've had zero problems with VLC. It does everything, plays everything. It streams. You can play movies as audio only so u can turn off the screen and fall to sleep listening to a movie. Pop up player is adjustable. I don't get why anyone would rate this less than maybe 4 stars, TBH.", "My go to when it comes to a 3rd party media player, but I've had a few issues. Mostly with background playback, in other apps and screen locked, where it would continue to play for a few seconds, and then go silent, opening with no media queued. EDIT OF THE EDIT: Also doesn't seem to happen over Blu...\nFull Review", 'Good media player for local storage, but frequently fails to browse network and load directories or play music, especially if connection is a bit slow. Once it fails, it usually needs be be closed and opened again. Would be happy to provide diagnostic information or help out to fix this, as otherwis...\nFull Review', "Great app when you think of playing many different media files. But impossible to bear on your mobile when you think of how much memory it occupies, and how many dozens of times a day it will repeat its media parsing again and again for countless minutes... Improve it, for God's sake. Solve that, pl...\nFull Review", "The Playlist experience is broken. If I change a Playlist, it doesn't auto-save like Microsoft Groove did. So I have to save the Playlist again. Except when I save over the existing Playlist, it appends the tracks to the existing Playlist instead of replacing the original list. So I have a playksit ...\nFull Review", "VLC for Android just isn't up to the standards of its PC counterpart. No matter what android device Ive used, I always run into some sort of hindrance when playing videos. Sound cutting out and not reappearing until I exit, video cutting out or distorting, etc etc. It finds a way to ruin anything I ...\nFull Review", 'With every update VLC becomes more unusable than the previous updates that predated it. Every video will have an issue such as macro blocking, audio suddenly turning off, or the video just randomly shutting off. Trying t ...
#  list(['417', '627', '97', '210', '22', '4', '18', '165', '169', '48', '137', '53', '216', '88', '6', '58', '134', '86', '47', '14', '24', '40', '124', '11', '61', '31', '23', '7', '42', '18', '20', '54', '28', '90', '6', '9', '5', '40', '29', '1357', '23', '8', '4', '36', '510', '2', '3', '5', '4', '27', '15', '7', '19', '19', '16', '1', '74', '11', '11', '5', '8', '20', '6', '3', '540', '10', '117', '15', '6', '27', '5', '3', '388', '4', '16', '7', '60', '55', '8', '8', '13', '8', '4', '48', '12', '6', '15', '4', '4', '36', '6', '150', '8', '143', '4', '72', '3', '14', '7', '4', '183', '40', '8', '6', '2', '5', '57', '85', '40', '5', '6', '2', '10', '7', '19', '', '338', '188', '88', '11', '12', '136', '150', '8', '183', '10', '10', '3', '', '18
February 10, 2020', 'February 13, 2020', 'December 10, 2019', 'December 6, 2019', 'December 27, 2019', 'January 27, 2020', 'February 6, 2020', 'February 12, 2020', 'January 25, 2020', 'February 4, 2020', 'January 31, 2020', 'February 18, 2020', 'January 10, 2020', 'December 30, 2019', 'December 19, 2019', 'January 23, 2020', 'February 1, 2020', 'December 13, 2019', 'December 15, 2019', 'February 2, 2020', 'December 31, 2019', 'January 22, 2020', 'January 28, 2020', 'February 7, 2020', 'February 17, 2020', 'February 1, 2020', 'December 22, 2019', 'January 26, 2020', 'February 12, 2020', 'February 5, 2020', 'February 10, 2020', 'January 22, 2020', 'February 5, 2020', 'December 31, 2019', 'December 28, 2019', 'February 6, 2020', 'December 20, 2019', 'December 4, 2019', 'December 9, 2019', 'December 5, 2019', 'February 14, 2020', 'December 27, 2019', 'January 16, 2020', 'February 2, 2020', 'February 3, 2020', 'February 18, 2020', 'December 27, 2019', 'December 11, 2019', 'December 18, 2019', 'December 31, 2019', 'December 14, 2019', 'December 17, 2019', 'December 23, 2019', 'January 14, 2020', 'January 23, 2020', 'December 13, 2019', 'December 6, 2019', 'December 23, 2019', 'December 7, 2019', 'December 15, 2019', 'December 18, 2019', 'December 20, 2019', 'December 29, 2019', 'January 8, 2020', 'January 11, 2020', 'January 23, 2020', 'January 27, 2020', 'December 21, 2019', 'January 29, 2020', 'February 14, 2020', 'January 2, 2020', 'December 21, 2019', 'December 31, 2019', 'December 19, 2019', 'January 4, 2020', 'January 13, 2020', 'January 23, 2020', 'January 27, 2020', 'January 23, 2020', 'December 5, 2019', 'December 21, 2019', 'January 8, 2020', 'February 2, 2020', 'December 4, 2019', 'February 10, 2020', 'February 12, 2020', 'February 11, 2020', 'December 18, 2019', 'January 2, 2020', 'January 9, 2020', 'January 17, 2020', 'January 19,  ...

# %%
rev = data_array[1]
# print(type(rev))
for i in range(len(data_array[1])):
    data_array[1][i] = data_array[1][i].replace('"','')
    data_array[1][i] = data_array[1][i].replace('...\nFull Review','')
    data_array[1][i] = data_array[1][i].replace('\n','')
    data_array[1][i] = data_array[1][i].replace('/','')
    data_array[1][i] = data_array[1][i].replace('\n','')
    data_array[1][i] = data_array[1][i].replace('br...','')

# %%
for i in range(len(data_array[3])):
    data_array[3][i] = data_array[3][i].replace('Rated','')
    data_array[3][i] = data_array[3][i].replace('stars out of five stars','')
    data_array[3][i] = data_array[3][i].replace(' ','')

# %%
data_array.reshape(5,-1)
# print(data_array[0].shape)
print(type(data_array),data_array.shape)

ds = []
columns = ['Name','Review','UpVotes','Rating','Date']
ds.append(columns)


for j in range(len(data_array[0])):
    temp = []
    for i in range(data_array.shape[0]):
#         print("i - ",i," j - ",j)
        temp.append(data_array[i][j])
    ds.append(temp)
# Out:
# <class 'numpy.ndarray'> (5,)

# %%
print(ds)
# Out:
# [['Name', 'Review', 'UpVotes', 'Rating', 'Date'], ['Shuttitt Uppitt', "(3.2.7) It works fine. It's smart to put the Delete option at the BOTTOM of the list. (At other users. Use FILE MANAGERS to delete videos images music others.) Now I hope to see better performance for non SUPER hardware. Example = One of my phones has 2 GB of RAM, but only 480x854 resolution. I", '417', '4.4', 'February 2, 2020'], ['Nate', 'Seek track is impossible to use. Whether I hold the fast forward or rewind button, tap the progress bar, drag the dot on the progress bar, or input seek time manually, nothing works. The behavior is erratic. This app is impossible to use for listening to audiobooks. 8 hours in one sitting with no br', '627', '5', 'February 4, 2020'], ['Sir Willard', "I've been using the VLC Windows application for years & it's better than any others I've tried. This was the reason for choosing this app. However, the most recent update shrank the tool bar to less than full screen width and removed the ability to refresh the play list after deleting a played file.", '97', '2', 'February 4, 2020'], ['Chris L', "The updates just make it worse. I used to like sorting by date to easily find my latest added files. Now you can only sort by name. I just don't understand how it got less features after an update. Lots of other small issues with the later versions also. I'm actively looking for a new app as this on", '210', '2', 'February 10, 2020'], ['Peter Blaikie', "I love VLC on my PC. Used to like it on my Android phone but it doesn't work on the S10+. I hate to give bad reviews but this app just doesn't work even after latest updates. Movies pauses every 2 seconds & doesn't restart. Time to look for a new video glare for android. I would prefer to use VLC, o", '22', '1', 'February 14, 2020'], ['Jermaine Rogers', "Glad to have the delete option back. Seems now the app has a problem keeping the filenames straight. Simply refreshing doesn't help. When I delete a file, the name is apparently assigned to a remaining file. I can only tell what the real filename is by looking at the information.", '4', '1', 'February 17, 2020'], ['Q B', "I've had zero problems with VLC. It does everything, plays everything. It streams. You can play movies as audio only so u can turn off the screen and fall to sleep listening to a movie. Pop up player is adjustable. I don't get why anyone would rate this less than maybe 4 stars, TBH.", '18', '2', 'February 14, 2020'], ['Shaun Samuel', "My go to when it comes to a 3rd party media player, but I've had a few issues. Mostly with background playback, in other apps and screen locked, where it would continue to play for a few seconds, and then go silent, opening with no media queued. EDIT OF THE EDIT: Also doesn't seem to happen over Blu", '165', '5', 'February 6, 2020'], ['Hamish McIntyre-Bhatty', 'Good media player for local storage, but frequently fails to browse network and load directories or play music, especially if connection is a bit slow. Once it fails, it usually needs be be closed and opened again. Would be happy to provide diagnostic information or help out to fix this, as otherwis', '169', '3', 'February 2, 2020'], ['Leonardo Hortmann', "Great app when you think of playing many different media files. But impossible to bear on your mobile when you think of how much memory it occupies, and how many dozens of times a day it will repeat its media parsing again and again for countless minutes... Improve it, for God's sake. Solve that, pl", '48', '3', 'February 12, 2020'], ['James Johnson', "The Playlist experience is broken. If I change a Playlist, it doesn't auto-save like Microsoft Groove did. So I have to save the Playlist again. Except when I save over the existing Playlist, it appends the tracks to the existing Playlist instead of replacing the original list. So I have a playksit ", '137', '1', 'February 8, 2020'], ['Nintendo Switch', "VLC for Android just isn't up to the standards of its PC counterpart. No mat ...

# %%
print(len(ds),len(ds[0]))
# Out:
# 841 5

# %%
with open("processed.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(ds)
