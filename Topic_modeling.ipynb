# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

# %%
n_top_words = 60

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ,".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
import pandas as pd
dataset = pd.read_excel("processed_batch (2).xlsx")
data_samples = dataset.OPINION_UNIT
data_samples = data_samples.dropna()
dataset
# Out:
#                    Reviewer        Review date  \
# 0           Shuttitt Uppitt   February 2, 2020
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
# 5                       NaN                NaN
# 6                       NaN                NaN
# 7                       NaN                NaN
# 8                        JD  February 16, 2020
# 9                       NaN                NaN
# 10                      NaN                NaN
# 11                      NaN                NaN
# 12                      NaN                NaN
# 13                     Nate   February 4, 2020
# 14                      NaN                NaN
# 15                      NaN                NaN
# 16                      NaN                NaN
# 17                      NaN                NaN
# 18                      NaN                NaN
# ...

# %%
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,stop_words='english')
tf = tf_vectorizer.fit_transform(data_samples)

# %%
lda = LatentDirichletAllocation(max_iter=20, n_components=3, learning_method='online',learning_offset=50.,random_state=0)
lda.fit(tf)
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
lda.fit(tf)
# Out:
# Topic #0: vlc ,video ,player ,update ,play ,screen ,app ,just ,download ,phone ,file ,videos ,used ,issue ,android ,pc ,use ,tried ,time ,music ,years ,best ,recent ,fit ,new ,audio ,fine ,cast ,files ,using ,like ,doesn ,media ,plays ,don ,able ,fix ,love ,fixed ,previous ,open ,want ,works ,playlists ,sort ,10 ,type ,tablet ,folder ,minimal ,mkv ,mx ,artifacts ,problem ,options ,playlist ,star ,click ,available ,ve
# Topic #1: fix ,just ,button ,like ,app ,forward ,work ,player ,gone ,hope ,media ,doesn ,updates ,files ,great ,couple ,good ,players ,new ,use ,help ,impossible ,using ,having ,isn ,did ,ads ,open ,user ,experience ,pls ,hours ,thanks ,stop ,play ,make ,used ,amazing ,bar ,manually ,load ,latest ,seek ,tv ,software ,think ,save ,frustrating ,pause ,playlist ,watching ,ago ,subtitles ,randomly ,problem ,home ,star ,edit ,available ,versions
# ...
